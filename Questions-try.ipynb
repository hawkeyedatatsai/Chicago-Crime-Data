# %% [markdown]
# # Read and concatenate Chicago Crime Data

# %%
import pandas as pd
import os, glob
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import dates as mdates
from matplotlib import ticker as mticks
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format',lambda x: f"{x:,.2f}")

# %%
# function for formatting money in thousands
def thousands(x, pos):
    xk = x/1000
    return f"${xk:,.0f}K"
str_fmt = mticks.FuncFormatter(thousands)

# %%
# find all csv file under Data/Chicago folder
path = 'Data/Chicago'
csv_files = glob.glob(path + "/*.csv")
csv_files.sort()
print(csv_files)
# Out:
# ['Data/Chicago/Chicago-Crime_2001.csv', 'Data/Chicago/Chicago-Crime_2002.csv', 'Data/Chicago/Chicago-Crime_2003.csv', 'Data/Chicago/Chicago-Crime_2004.csv', 'Data/Chicago/Chicago-Crime_2005.csv', 'Data/Chicago/Chicago-Crime_2006.csv', 'Data/Chicago/Chicago-Crime_2007.csv', 'Data/Chicago/Chicago-Crime_2008.csv', 'Data/Chicago/Chicago-Crime_2009.csv', 'Data/Chicago/Chicago-Crime_2010.csv', 'Data/Chicago/Chicago-Crime_2011.csv', 'Data/Chicago/Chicago-Crime_2012.csv', 'Data/Chicago/Chicago-Crime_2013.csv', 'Data/Chicago/Chicago-Crime_2014.csv', 'Data/Chicago/Chicago-Crime_2015.csv', 'Data/Chicago/Chicago-Crime_2016.csv', 'Data/Chicago/Chicago-Crime_2017.csv', 'Data/Chicago/Chicago-Crime_2018.csv', 'Data/Chicago/Chicago-Crime_2019.csv', 'Data/Chicago/Chicago-Crime_2020.csv', 'Data/Chicago/Chicago-Crime_2021.csv', 'Data/Chicago/Chicago-Crime_2022.csv', 'Data/Chicago/Chicago-Crime_2023.csv']

# %%
# read and merge all csv_files
df = pd.concat([pd.read_csv(file) for file in csv_files ], ignore_index=True)
display(df.head(),df.tail())
# Out:
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/4248295058.py:2: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([pd.read_csv(file) for file in csv_files ], ignore_index=True)
#         ID                    Date     Primary Type  \
# 0  3723059  01/01/2001 12:00:00 AM            THEFT
# 1  1322043  01/01/2001 12:00:00 AM  CRIMINAL DAMAGE
# 2  1968773  01/01/2001 12:00:00 AM            THEFT
# 3  5952122  01/01/2001 12:00:00 AM            THEFT
# 4  1312179  01/01/2001 12:00:00 AM  CRIMINAL DAMAGE
#
#                      Description Location Description Arrest Domestic  \
# 0  FINANCIAL ID THEFT: OVER $300            APARTMENT  False    False
# 1                    TO PROPERTY            RESIDENCE  False    False
# 2  FINANCIAL ID THEFT: OVER $300            RESIDENCE  False    False
# 3  FINANCIAL ID THEFT: OVER $300            APARTMENT  False    False
# 4                    TO PROPERTY            RESIDENCE  False    False
#
#       Beat  District  Ward  Latitude  Longitude
# 0   732.00      7.00  6.00     41.77     -87.64
# 1   825.00      8.00   NaN     41.78     -87.68
# 2 2,022.00     20.00   NaN     41.99     -87.66
# 3 1,431.00     14.00  1.00     41.92     -87.70
# 4 1,533.00     15.00   NaN     41.87     -87.75
#                ID                    Date            Primary Type  \
# 7029995  13120947  06/26/2023 11:42:00 PM                   THEFT
# 7029996  13120829  06/26/2023 11:43:00 PM                   THEFT
# 7029997  13120830  06/26/2023 11:46:00 PM                 BATTERY
# 7029998  13120820  06/26/2023 11:50:00 PM  PUBLIC PEACE VIOLATION
# 7029999  13120824  06/26/2023 11:59:00 PM                 ROBBERY
#
#                      Description Location Description Arrest Domestic  \
# 7029995           $500 AND UNDER            APARTMENT  False    False
# 7029996             RETAIL THEFT          GAS STATION  False    False
# 7029997  DOMESTIC BATTERY SIMPLE            APARTMENT  False     True
# 7029998          OTHER VIOLATION         CTA PLATFORM  False    False
# 7029999          ARMED - HANDGUN           RESTAURANT  False    False
#
#             Beat  District  Ward  Latitude  Longitude
# 7029995   321.00      3.00 20.00     41.77     -87.61
# 7029996   923.00      9.00 14.00     41.79     -87.69
# 7029997   932.00      9.00 16.00     41.80     -87.68
# 7029998   123.00      1.00 34.00     41.88     -87.63
# 7029999 2,423.00     24.00 49.00     42.01     -87.67

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7030000 entries, 0 to 7029999
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Date                  object
#  2   Primary Type          object
#  3   Description           object
#  4   Location Description  object
#  5   Arrest                object
#  6   Domestic              object
#  7   Beat                  float64
#  8   District              float64
#  9   Ward                  float64
#  10  Latitude              float64
#  11  Longitude             float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 643.6+ MB

# %% [markdown]
# # Create two forms of data

# %%
# Original format: convert Date to datetime dtype
df['Date'] = pd.to_datetime(df['Date'],
                           format = '%m/%d/%Y %I:%M:%S %p')

# set the datetime column as the index
df = df.set_index('Date')
df.head()
# Out:
#                  ID     Primary Type                    Description  \
# Date
# 2001-01-01  3723059            THEFT  FINANCIAL ID THEFT: OVER $300
# 2001-01-01  1322043  CRIMINAL DAMAGE                    TO PROPERTY
# 2001-01-01  1968773            THEFT  FINANCIAL ID THEFT: OVER $300
# 2001-01-01  5952122            THEFT  FINANCIAL ID THEFT: OVER $300
# 2001-01-01  1312179  CRIMINAL DAMAGE                    TO PROPERTY
#
#            Location Description Arrest Domestic     Beat  District  Ward  \
# Date
# 2001-01-01            APARTMENT  False    False   732.00      7.00  6.00
# 2001-01-01            RESIDENCE  False    False   825.00      8.00   NaN
# 2001-01-01            RESIDENCE  False    False 2,022.00     20.00   NaN
# 2001-01-01            APARTMENT  False    False 1,431.00     14.00  1.00
# 2001-01-01            RESIDENCE  False    False 1,533.00     15.00   NaN
#
#             Latitude  Longitude
# Date
# 2001-01-01     41.77     -87.64
# 2001-01-01     41.78     -87.68
# 2001-01-01     41.99     -87.66
# 2001-01-01     41.92     -87.70
# 2001-01-01     41.87     -87.75

# %%
# A resampled/converted crime counts version 
# alternate code:
resampled_df = df.copy()
# add 'Count' column with 1 for each row
resampled_df['Count'] = 1
# resample and count with .sum()
resampled_df = resampled_df.resample('D').sum(numeric_only = True)
#resampled_df = resampled_df.resample('D').sum(numeric_only = False)

# check
resampled_df.head()
# Out:
#                     ID         Beat  District     Ward  Latitude   Longitude  \
# Date
# 2001-01-01  4011740634 2,267,987.00 21,147.00 8,194.00 72,641.08 -152,199.72
# 2001-01-02  1545846568 1,404,493.00 12,797.00   147.00 47,664.67  -99,856.85
# 2001-01-03  1542074517 1,462,886.00 13,359.00   132.00 48,045.81 -100,651.35
# 2001-01-04  1555657957 1,397,040.00 12,994.00     0.00 48,785.52 -102,222.92
# 2001-01-05  1701884634 1,530,155.00 14,044.00   156.00 52,769.46 -110,554.59
#
#             Count
# Date
# 2001-01-01   1825
# 2001-01-02   1143
# 2001-01-03   1151
# 2001-01-04   1166
# 2001-01-05   1267

# %% [markdown]
# # Topic 1) Comparing Police Districts:

# %% [markdown]
# ## Which district has the most crimes? Which has the least?

# %%
# create a barplot function
def plot_bar(df, y_column, pale, yticks, ylab):
  fig, axes = plt.subplots(nrows=1, figsize=(15,5), sharex=True)
  g = sns.countplot(data=df, y=y_column, 
              palette=pale, order = df[y_column].value_counts().index)
  g.set(yticklabels=yticks);
  g.set_xlabel('Counts');
  g.set_ylabel(ylab);
  g.set_title(f'Count of Each {ylab}', fontsize=14, weight = 'bold');

  total = float(len(df))
  for p in g.patches:
      count = round(p.get_width())
      y = p.get_y() + p.get_height()-0.3
      x = p.get_width()
      g.annotate(count, (x, y),ha='left')
        
  FOLDER = "PNG/"
  isExist = os.path.exists(FOLDER)
    
  if isExist == False:  
      os.makedirs(FOLDER, exist_ok=True)
        
  plt.savefig(f'{FOLDER}/{y_column}_barplot.png',bbox_inches='tight')

  return fig,g

# %%
# number of crimes per district
count_by_dis = df['District'].value_counts().rename_axis('District').to_frame('Count')
count_by_dis = count_by_dis.reset_index()
display(count_by_dis.head(1),count_by_dis.tail(1))
# Out:
#    District   Count
# 0      8.00  473042
#     District  Count
# 23     21.00      4

# %%
# create a barplot for district column
yticks = count_by_dis['District']
pale = sns.color_palette("Set3", count_by_dis.shape[0])
pale
# Out:
# [(0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254),
#  (0.7450980392156863, 0.7294117647058823, 0.8549019607843137),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118),
#  (0.5019607843137255, 0.6941176470588235, 0.8274509803921568),
#  (0.9921568627450981, 0.7058823529411765, 0.3843137254901961),
#  (0.7019607843137254, 0.8705882352941177, 0.4117647058823529),
#  (0.9882352941176471, 0.803921568627451, 0.8980392156862745),
#  (0.8509803921568627, 0.8509803921568627, 0.8509803921568627),
#  (0.7372549019607844, 0.5019607843137255, 0.7411764705882353),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (1.0, 0.9294117647058824, 0.43529411764705883),
#  (0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254),
#  (0.7450980392156863, 0.7294117647058823, 0.8549019607843137),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118),
#  (0.5019607843137255, 0.6941176470588235, 0.8274509803921568),
#  (0.9921568627450981, 0.7058823529411765, 0.3843137254901961),
#  (0.7019607843137254, 0.8705882352941177, 0.4117647058823529),
#  (0.9882352941176471, 0.803921568627451, 0.8980392156862745),
#  (0.8509803921568627, 0.8509803921568627, 0.8509803921568627),
#  (0.7372549019607844, 0.5019607843137255, 0.7411764705882353),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (1.0, 0.9294117647058824, 0.43529411764705883)]

# %%
# plot crime counts by district
plot_bar(df,
         y_column='District',
         pale=pale, yticks = yticks, ylab = 'District');

# %% [markdown]
# District 8 and 21 are the most and least cases in this time period.

# %% [markdown]
# # Topic 2) Crimes Across the Years:

# %% [markdown]
# ## Is the total number of crimes increasing or decreasing across the years?

# %%
# resample resampled_df from daily to yearly
crime_year = resampled_df.resample('AS')['Count'].sum().reset_index()
crime_year['Date'] = pd.to_datetime(crime_year['Date'])
crime_year = crime_year.set_index('Date')
crime_year
# Out:
#              Count
# Date
# 2001-01-01  485754
# 2002-01-01  486799
# 2003-01-01  475972
# 2004-01-01  469402
# 2005-01-01  453753
# 2006-01-01  448168
# 2007-01-01  437068
# 2008-01-01  427161
# 2009-01-01  392816
# 2010-01-01  369798
# 2011-01-01  350698
# 2012-01-01  153025
# 2013-01-01    5327
# 2014-01-01    6752
# 2015-01-01  218582
# 2016-01-01  269802
# 2017-01-01  269087
# 2018-01-01  268796
# 2019-01-01  261272
# 2020-01-01  212153
# 2021-01-01  208681
# 2022-01-01  238643
# 2023-01-01  120491

# %%
# plot new yearly resampled_df

## create tick locators and formatters
loc_5year = mdates.YearLocator(5)
fmt_year = mdates.DateFormatter("%Y")
loc_year = mdates.YearLocator(1)

plt.rcParams['figure.figsize'] = (10,3)
fig, ax = plt.subplots()
ax.plot(crime_year.index, crime_year.values)

ax.set_title('Change in Number of Crimes from 2001-2023', fontsize=14, weight = 'bold')
ax.set_ylabel('# of Crimes')

ax.xaxis.set_major_locator(loc_5year)
ax.xaxis.set_major_formatter(fmt_year)
ax.xaxis.set_minor_locator(loc_year)

ax.yaxis.set_major_formatter(str_fmt)

fig = ax.get_figure()
fig.autofmt_xdate(rotation = 90, ha = 'center')

# %%
## save to PNG
FOLDER = 'PNG/'
fig.savefig(f'{FOLDER}/change-crime-yearly.png',bbox_inches='tight')

# %% [markdown]
# from the plot above, we can see the number of crimes does not increase across the year. There was a significant drop on 2013 and 2014 with less than 7000 crimes, and then on 2015 the number climbs back to 20000 crimes. After that, another tick on 2022. Overall, it is a decreasing trend.

# %% [markdown]
# ## Are there any individual crimes that are doing the opposite (e.g decreasing when overall crime is increasing or vice-versa)?

# %%
# use original df where each row is a crime
# add a count columns to be used later
df['Count'] = 1
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7030000 entries, 2001-01-01 00:00:00 to 2023-06-26 23:59:00
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Primary Type          object
#  2   Description           object
#  3   Location Description  object
#  4   Arrest                object
#  5   Domestic              object
#  6   Beat                  float64
#  7   District              float64
#  8   Ward                  float64
#  9   Latitude              float64
#  10  Longitude             float64
#  11  Count                 int64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 697.3+ MB
# None
#                  ID     Primary Type                    Description  \
# Date
# 2001-01-01  3723059            THEFT  FINANCIAL ID THEFT: OVER $300
# 2001-01-01  1322043  CRIMINAL DAMAGE                    TO PROPERTY
# 2001-01-01  1968773            THEFT  FINANCIAL ID THEFT: OVER $300
# 2001-01-01  5952122            THEFT  FINANCIAL ID THEFT: OVER $300
# 2001-01-01  1312179  CRIMINAL DAMAGE                    TO PROPERTY
#
#            Location Description Arrest Domestic     Beat  District  Ward  \
# Date
# 2001-01-01            APARTMENT  False    False   732.00      7.00  6.00
# 2001-01-01            RESIDENCE  False    False   825.00      8.00   NaN
# 2001-01-01            RESIDENCE  False    False 2,022.00     20.00   NaN
# 2001-01-01            APARTMENT  False    False 1,431.00     14.00  1.00
# 2001-01-01            RESIDENCE  False    False 1,533.00     15.00   NaN
#
#             Latitude  Longitude  Count
# Date
# 2001-01-01     41.77     -87.64      1
# 2001-01-01     41.78     -87.68      1
# 2001-01-01     41.99     -87.66      1
# 2001-01-01     41.92     -87.70      1
# 2001-01-01     41.87     -87.75      1

# %%
# create a yearly data and groupby each Primary Type
# Resample the dataframe grouped by month
crime_year_type = df.groupby(['Primary Type']).resample('A')['Count'].sum().reset_index()
#crime_year_type = df.groupby(['Primary Type']).resample('A')['Count'].sum()
crime_year_type
# Out:
#           Primary Type       Date  Count
# 0                ARSON 2001-12-31   1011
# 1                ARSON 2002-12-31   1032
# 2                ARSON 2003-12-31    955
# 3                ARSON 2004-12-31    778
# 4                ARSON 2005-12-31    691
# ..                 ...        ...    ...
# 743  WEAPONS VIOLATION 2019-12-31   6339
# 744  WEAPONS VIOLATION 2020-12-31   8432
# 745  WEAPONS VIOLATION 2021-12-31   8980
# 746  WEAPONS VIOLATION 2022-12-31   8766
# 747  WEAPONS VIOLATION 2023-12-31   4203
#
# [748 rows x 3 columns]

# %%
crime_year_type.index
# Out:
# RangeIndex(start=0, stop=748, step=1)

# %%
g = sns.catplot(data=crime_year_type, x='Date', y='Count',
                kind='point',aspect=3, height=4,
                hue='Primary Type', col='Primary Type',col_wrap=2,
               sharey=False, sharex=False)
# Rotate the x-axis labels by 90 degrees
g.set_xticklabels(rotation=90)

[ax.grid(axis='x') for ax in g.axes]
plt.tight_layout();

# %%
## Save to PNG
FOLDER = "PNG/"
fig.savefig(f'{FOLDER}/each-crime-by-year.png',bbox_inches='tight')

# %%
# convert the long-form to separate each primary type to a separate column
# pivot the result to have the datetime as the index and the crime as the columns
crime_year_type = crime_year_type.dropna()
crime_year_type_piv = crime_year_type.pivot(index = 'Date', columns = 'Primary Type')
crime_year_type_piv.head()
# Out:
#                 Count                                \
# Primary Type    ARSON   ASSAULT   BATTERY  BURGLARY
# Date
# 2001-12-31   1,011.00 31,384.00 93,460.00 26,014.00
# 2002-12-31   1,032.00 31,523.00 94,152.00 25,623.00
# 2003-12-31     955.00 29,476.00 88,375.00 25,157.00
# 2004-12-31     778.00 28,850.00 87,135.00 24,563.00
# 2005-12-31     691.00 27,067.00 83,962.00 25,500.00
#
#                                                                     \
# Primary Type CONCEALED CARRY LICENSE VIOLATION CRIM SEXUAL ASSAULT
# Date
# 2001-12-31                                1.00            1,779.00
# 2002-12-31                                0.00            1,807.00
# 2003-12-31                                0.00            1,571.00
# 2004-12-31                                0.00            1,539.00
# 2005-12-31                                0.00            1,521.00
#
#                                                                         \
# Primary Type CRIMINAL DAMAGE CRIMINAL SEXUAL ASSAULT CRIMINAL TRESPASS
# Date
# 2001-12-31         55,858.00                   29.00         13,241.00
# 2002-12-31         55,941.00                   27.00         13,880.00
THER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  \
# Date
# 2001-12-31        29,663.00      6,026.00              9.00
# 2002-12-31        32,599.00      6,407.00              8.00
# 2003-12-31        31,147.00      6,212.00              6.00
# 2004-12-31        29,530.00      7,475.00              9.00
# 2005-12-31        28,027.00      6,123.00              4.00
#
# Primary Type  PUBLIC PEACE VIOLATION  RITUALISM   ROBBERY  SEX OFFENSE  \
# Date
# 2001-12-31                  2,750.00       8.00 18,441.00     2,239.00
# 2002-12-31                  2,457.00       2.00 18,523.00     2,173.00
# 2003-12-31                  2,430.00       2.00 17,332.00     2,078.00
# 2004-12-31                  2,495.00       1.00 15,977.00     1,805.00
# 2005-12-31                  2,730.00       2.00 16,047.00     1,815.00
#
# Primary Type  STALKING     THEFT  WEAPONS VIOLATION
# Date
# 2001-12-31      204.00 99,277.00           4,277.00
# 2002-12-31      200.00 98,331.00           4,281.00
# 2003-12-31      247.00 98,874.00           4,211.00
# 2004-12-31      215.00 95,461.00           4,298.00
# 2005-12-31      192.00 85,683.00           4,106.00

# %%
# subtract to get delta crimes
change_crime_years = crime_year_type_piv.loc['2023-12-31'] - crime_year_type_piv.loc['2001-12-31']
change_crime_years
# Out:
# Primary Type
# ARSON                                  -773.00
# ASSAULT                             -20,928.00
# BATTERY                             -72,926.00
# BURGLARY                            -22,525.00
# CONCEALED CARRY LICENSE VIOLATION        88.00
# CRIM SEXUAL ASSAULT                        NaN
# CRIMINAL DAMAGE                     -42,001.00
# CRIMINAL SEXUAL ASSAULT                 698.00
# CRIMINAL TRESPASS                   -10,981.00
# DECEPTIVE PRACTICE                   -7,382.00
# DOMESTIC VIOLENCE                          NaN
# GAMBLING                               -930.00
# HOMICIDE                               -243.00
# HUMAN TRAFFICKING                          NaN
# INTERFERENCE WITH PUBLIC OFFICER       -123.00
# INTIMIDATION                           -143.00
# KIDNAPPING                             -873.00
# LIQUOR LAW VIOLATION                 -1,540.00
# MOTOR VEHICLE THEFT                 -13,402.00
# NARCOTICS                           -48,216.00
# NON - CRIMINAL                             NaN
# NON-CRIMINAL                               NaN
# NON-CRIMINAL (SUBJECT SPECIFIED)           NaN
# OBSCENITY                                -3.00
# OFFENSE INVOLVING CHILDREN           -1,333.00
# OTHER NARCOTIC VIOLATION                 -4.00
# OTHER OFFENSE                       -22,279.00
# PROSTITUTION                         -5,904.00
# PUBLIC INDECENCY                         -6.00
# PUBLIC PEACE VIOLATION               -2,336.00
# RITUALISM                                  NaN
# ROBBERY                             -14,096.00
# SEX OFFENSE                          -1,634.00
# STALKING                                  8.00
# THEFT                               -73,620.00
# WEAPONS VIOLATION                       -74.00
# dtype: float64

# %%
# drop the missing values in change_crime_years
change_crime_years = change_crime_years.dropna().to_frame('Count')
change_crime_years = change_crime_years.sort_values(by = 'Count',ascending=False)
change_crime_years = change_crime_years.reset_index()
change_crime_years
# Out:
#                          Primary Type      Count
# 0             CRIMINAL SEXUAL ASSAULT     698.00
# 1   CONCEALED CARRY LICENSE VIOLATION      88.00
# 2                            STALKING       8.00
# 3                           OBSCENITY      -3.00
# 4            OTHER NARCOTIC VIOLATION      -4.00
# 5                    PUBLIC INDECENCY      -6.00
# 6                   WEAPONS VIOLATION     -74.00
# 7    INTERFERENCE WITH PUBLIC OFFICER    -123.00
# 8                        INTIMIDATION    -143.00
# 9                            HOMICIDE    -243.00
# 10                              ARSON    -773.00
# 11                         KIDNAPPING    -873.00
# 12                           GAMBLING    -930.00
# 13         OFFENSE INVOLVING CHILDREN  -1,333.00
# 14               LIQUOR LAW VIOLATION  -1,540.00
# 15                        SEX OFFENSE  -1,634.00
# 16             PUBLIC PEACE VIOLATION  -2,336.00
# 17                       PROSTITUTION  -5,904.00
# 18                 DECEPTIVE PRACTICE  -7,382.00
# 19                  CRIMINAL TRESPASS -10,981.00
# 20                MOTOR VEHICLE THEFT -13,402.00
# 21                            ROBBERY -14,096.00
# 22                            ASSAULT -20,928.00
# 23                      OTHER OFFENSE -22,279.00
# 24                           BURGLARY -22,525.00
# 25                    CRIMINAL DAMAGE -42,001.00
# 26                          NARCOTICS -48,216.00
# 27                            BATTERY -72,926.00
# 28                              THEFT -73,620.00

# %% [markdown]
# There are three primary types of crime that have increased between 2001 and 2023 despite the overall trend of decrease in crime. They are
# CRIMINAL SEXUAL ASSAULT, CONCEALED CARRY LICENSE VIOLATION and STALKING.

# %%
# plot the changes
plt.rcParams['figure.figsize'] = (12,3)
fig, ax = plt.subplots()
sns.barplot(data=change_crime_years, x='Primary Type' ,y='Count')
ax.set_title('Change of crime by type from 2001 to 2023', fontsize=14, weight = 'bold')
fig = ax.get_figure()
fig.autofmt_xdate(rotation = 90, ha = 'center')

# %%
## Save to PNG
FOLDER = "PNG/"
fig.savefig(f'{FOLDER}/change-crime-by-type.png',bbox_inches='tight')

# %% [markdown]
# # Topic 4) Comparing Months:

# %% [markdown]
# ## What months have the most crime? What months have the least?

# %%
# group by month
df_monthcount = resampled_df.copy()
df_monthcount['Month'] = df_monthcount.index.month
df_monthcount['MonthName'] = df_monthcount.index.month_name()
df_monthcount = df_monthcount.reset_index()
df_monthcount = df_monthcount.groupby(['Month','MonthName'])['Count'].sum().to_frame('Count')
df_monthcount = df_monthcount.reset_index()
df_monthcount.sort_values('Count',ascending=False)
# Out:
#     Month  MonthName   Count
# 4       5        May  651841
# 5       6       June  633681
# 6       7       July  631242
# 7       8     August  627096
# 9      10    October  600059
# 3       4      April  599493
# 2       3      March  592141
# 8       9  September  591391
# 0       1    January  557276
# 10     11   November  539799
# 11     12   December  512891
# 1       2   February  493090

# %% [markdown]
# The month of May and February have the highest and lowest number of crimes.

# %%
# plot the changes
plt.rcParams['figure.figsize'] = (12,3)
fig, ax = plt.subplots()
sns.barplot(data=df_monthcount, x='Month' ,y='Count')
ax.set_title('Crime by Month', fontsize=14, weight = 'bold')
ax.set(xticklabels = (list(df_monthcount['MonthName'])))
ax.set_xlabel('')
fig = ax.get_figure()
fig.autofmt_xdate(rotation = 90, ha = 'center')

# %%
## Save to PNG
FOLDER = "PNG/"
fig.savefig(f'{FOLDER}/crime-by-month.png',bbox_inches='tight')

# %% [markdown]
# ## Are there any individual crimes that do not follow this pattern? If so, which crimes?

# %%
# create a yearly data and group by each Primary Type
# Resample the dataframe grouped by month
crime_mo_type = df.groupby(['Primary Type']).resample('MS')['Count'].sum().reset_index()
crime_mo_type['Month'] = crime_mo_type['Date'].dt.month
crime_mo_type['MonthName'] = crime_mo_type['Date'].dt.month_name()
crime_mo_type
# Out:
#            Primary Type       Date  Count  Month MonthName
# 0                 ARSON 2001-01-01     67      1   January
# 1                 ARSON 2001-02-01     57      2  February
# 2                 ARSON 2001-03-01     93      3     March
# 3                 ARSON 2001-04-01     89      4     April
# 4                 ARSON 2001-05-01     94      5       May
# ...                 ...        ...    ...    ...       ...
# 8722  WEAPONS VIOLATION 2023-02-01    641      2  February
# 8723  WEAPONS VIOLATION 2023-03-01    631      3     March
# 8724  WEAPONS VIOLATION 2023-04-01    688      4     April
# 8725  WEAPONS VIOLATION 2023-05-01    822      5       May
# 8726  WEAPONS VIOLATION 2023-06-01    681      6      June
#
# [8727 rows x 5 columns]

# %%
# group data
crime_mo_type = crime_mo_type.groupby(['Month','MonthName','Primary Type'])['Count'].sum().to_frame('Count')
crime_mo_type = crime_mo_type.reset_index()
crime_mo_type
# Out:
#      Month MonthName                       Primary Type   Count
# 0        1   January                              ARSON     895
# 1        1   January                            ASSAULT   32941
# 2        1   January                            BATTERY   93813
# 3        1   January                           BURGLARY   29571
# 4        1   January  CONCEALED CARRY LICENSE VIOLATION      82
# ..     ...       ...                                ...     ...
# 414     12  December                            ROBBERY   22553
# 415     12  December                        SEX OFFENSE    1746
# 416     12  December                           STALKING     291
# 417     12  December                              THEFT  110885
# 418     12  December                  WEAPONS VIOLATION    6690
#
# [419 rows x 4 columns]

# %%
g = sns.catplot(data=crime_mo_type, x='Month', y='Count',
                kind='point',aspect=2, height=4,
                hue='Primary Type', col='Primary Type',col_wrap=2,
               sharey=False, sharex=False)
[ax.grid(axis='x') for ax in g.axes];

# %%
## Save to PNG
FOLDER = "PNG/"
fig.savefig(f'{FOLDER}/each-crime-by-month.png',bbox_inches='tight')

# %%
crime_mo_type_piv = crime_mo_type.pivot(index = ['Month','MonthName'], columns = 'Primary Type')
crime_mo_type_piv
# Out:
#                    Count                                 \
# Primary Type       ARSON   ASSAULT    BATTERY  BURGLARY
# Month MonthName
# 1     January     895.00 32,941.00  93,813.00 29,571.00
# 2     February    772.00 31,674.00  87,196.00 23,522.00
# 3     March     1,062.00 39,855.00 110,715.00 27,913.00
# 4     April     1,073.00 40,863.00 113,373.00 29,496.00
# 5     May       1,199.00 46,986.00 129,683.00 33,897.00
# 6     June      1,179.00 44,796.00 126,695.00 32,798.00
# Month MonthName
# 1     January                 3,001.00      3.00 21,640.00    2,556.00
# 2     February                2,957.00      1.00 16,131.00    1,932.00
# 3     March                   4,088.00      3.00 19,149.00    2,287.00
# 4     April                   3,895.00      1.00 20,099.00    2,226.00
# 5     May                     4,913.00      1.00 22,677.00    2,717.00
# 6     June                    4,346.00      0.00 22,682.00    2,753.00
# 7     July                    3,872.00      1.00 23,793.00    2,792.00
# 8     August                  3,618.00      3.00 24,153.00    2,608.00
# 9     September               4,039.00      3.00 23,086.00    2,514.00
# 10    October                 4,006.00      3.00 24,605.00    2,247.00
# 11    November                3,060.00      2.00 22,568.00    1,973.00
# 12    December                2,670.00      3.00 22,553.00    1,746.00
#
#
# Primary Type    STALKING      THEFT WEAPONS VIOLATION
# Month MonthName
# 1     January     389.00 113,371.00          7,913.00
# 2     February    327.00  97,059.00          6,482.00
# 3     March       404.00 116,074.00          8,169.00
# 4     April       403.00 119,459.00          8,537.00
# 5     May         411.00 130,436.00         10,102.00
# 6     June        405.00 131,832.00          9,308.00
# 7     July        385.00 138,566.00          8,792.00
# 8     August      361.00 139,056.00          8,924.00
# 9     September   345.00 127,194.00          8,499.00
# 10    October     357.00 128,819.00          8,390.00
# 11    November    362.00 114,972.00          7,235.00
# 12    December    291.00 110,885.00          6,690.00

# %%
# drop the first level of columns
crime_mo_type_piv.columns = crime_mo_type_piv.columns.droplevel(0)
crime_mo_type_piv = crime_mo_type_piv.reset_index()
crime_mo_type_piv
# Out:
# Primary Type  Month  MonthName    ARSON   ASSAULT    BATTERY  BURGLARY  \
# 0                 1    January   895.00 32,941.00  93,813.00 29,571.00
# 1                 2   February   772.00 31,674.00  87,196.00 23,522.00
# 2                 3      March 1,062.00 39,855.00 110,715.00 27,913.00
# 3                 4      April 1,073.00 40,863.00 113,373.00 29,496.00
# 4                 5        May 1,199.00 46,986.00 129,683.00 33,897.00
# 5                 6       June 1,179.00 44,796.00 126,695.00 32,798.00
# 6                 7       July 1,210.00 42,774.00 120,998.00 34,080.00
# 7                 8     August 1,057.00 41,402.00 113,738.00 35,286.00
# 8                 9  September 1,032.00 40,676.00 108,790.00 33,500.00
# 9                10    October 1,039.00 38,266.00 105,714.00 34,519.00
# 10               11   November   935.00 32,615.00  91,412.00 32,488.00
# 11               12   December   847.00 30,606.00  87,072.00 31,086.00
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# 0                                         82.00             2,279.00
# 1                                         81.00             1,677.00
# 2                                         90.00             1,866.00
# 3                                         88.00             1,933.00
# 4                                        104.00             2,186.00
# 5                                        108.00             2,211.00
# 6                                         93.00             2,302.00
# 7                                         96.00             2,219.00
# 8                                        116.00             2,139.00
# 9                                         96.00             2,024.00
# 10                                        72.00             1,728.00
# 11                                        63.00             1,594.00
#
# Primary Type  CRIMINAL DAMAGE  CRIMINAL SEXUAL ASSAULT  CRIMINAL TRESPASS  \
# 0                   58,815.00                   644.00          16,979.00
# 1                   52,449.00                   531.00          15,448.00
# 2                   68,346.00                   610.00          17,490.00
# 3                   72,422.00                   554.00          16,757.00
# 4                   76,724.00                   672.00          17,405.00
# 5                   74,276.00                   698.00          16,156.00
# 6                   74,553.00                   590.00          15,887.00
# 7                   73,169.00                   572.00          16,367.00
# 8                   67,543.00                   541.00          15,991.00
# 9                   72,094.00                   569.00          16,294.00
# 10                  64,254.00                   493.00          14,983.00
# 11                  56,192.00                   460.00          14,180.00
#
# Primary Type  DECEPTIVE PRACTICE  DOMESTIC VIOLENCE  GAMBLING  HOMICIDE  \
# 0                      28,223.00               1.00    354.00    839.00
# 1                      23,603.00                NaN    372.00    689.00
# 2                      26,892.00                NaN    707.00    831.00
# 3                      26,497.00                NaN  1,149.00  1,018.00
# 4                      26,291.00                NaN  1,515.00  1,182.00
# 5                      26,194.00                NaN  1,676.00  1,288.00
# 6                      25,121.00                NaN  1,703.00  1,310.00
# 7                      25,634.00                NaN  1,944.00  1,240.00
# 8                      24,616.00                NaN  1,572.00  1,211.00
# 9                      26,065.00                NaN  1,164.00  1,081.00
# 10                     24,556.00                NaN    683.00    965.00
# 11                     26,626.00                NaN    321.00    898.00
#
# Primary Type  HUMAN TRAFFICKING  INTERFERENCE WITH PUBLIC OFFICER  \
# 0                         13.00                          1,063.00
# 1                         11.00                          1,105.00
# 2                         11.00                          1,272.00
# 3                          3.00                          1,252.00
# 4                          6.00                          1,433.00
# 5                         10.00                          1,414.00
# 6                          8.00                          1,404.00
# 7                          9.00                          1,397.00
# 8                         14.00                          1,334.00
# 9                          9.00                          1,223.00
# 10                         2.00                          1,076.00
# 11                         3.00                            928.00
#
# Primary Type  INTIMIDATION  KIDNAPPING  LIQUOR LAW VIOLATION  \
# 0                   364.00      551.00              1,067.00
# 1                   299.00      476.00              1,030.00
# 2                   393.00      575.00              1,347.00
# 3                   379.00      539.00              1,291.00
# 4                   404.00      661.00              1,315.00
# 5                   383.00      632.00              1,372.00
# 6                   383.00      564.00              1,252.00
# 7                   363.00      515.00              1,182.00
# 8                   399.00      557.00              1,133.00
# 9                   411.00      481.00              1,104.00
# 10                  297.00      532.00                976.00
# 11                  287.00      538.00                696.00
#
# Primary Type  MOTOR VEHICLE THEFT  NARCOTICS  NON - CRIMINAL  NON-CRIMINAL  \
# 0                       29,987.00  59,119.00            1.00         10.00
# 1                       24,774.00  57,507.00            4.00         11.00
# 2                       28,625.00  62,362.00             NaN         11.00
# 3                       28,570.00  57,774.00             NaN         11.00
# 4                       30,368.00  57,850.00            3.00         12.00
# 5                       29,909.00  52,847.00            7.00         15.00
# 6                       29,323.00  53,077.00            0.00          9.00
# 7                       29,512.00  56,190.00            2.00         15.00
# 8                       28,610.00  53,387.00            3.00         14.00
# 9                       30,574.00  54,185.00            1.00         19.00
# 10                      28,523.00  51,853.00            1.00         18.00
# 11                      28,868.00  47,532.00            1.00         12.00
#
# Primary Type  NON-CRIMINAL (SUBJECT SPECIFIED)  OBSCENITY  \
# 0                                         1.00      73.00
# 1                                         1.00      49.00
# 2                                         1.00      86.00
# 3                                         1.00      50.00
# 4                                         0.00      69.00
# 5                                         0.00      59.00
# 6                                         1.00      63.00
# 7                                         1.00      49.00
# 8                                         0.00      62.00
# 9                                         0.00      88.00
# 10                                        0.00      50.00
# 11                                        0.00      52.00
#
# Primary Type  OFFENSE INVOLVING CHILDREN  OTHER NARCOTIC VIOLATION  \
# 0                               5,663.00                      8.00
# 1                               3,637.00                     12.00
# 2                               4,236.00                     11.00
# 3                               4,244.00                      8.00
# 4                               4,626.00                     17.00
# 5                               4,352.00                      7.00
# 6                               4,011.00                     16.00
# 7                               4,047.00                     13.00
# 8                               3,898.00                     12.00
# 9                               3,806.00                      4.00
# 10                              3,587.00                     12.00
# 11                              3,795.00                      7.00
#
# Primary Type  OTHER OFFENSE  PROSTITUTION  PUBLIC INDECENCY  \
# 0                 39,011.00      6,029.00              7.00
# 1                 35,969.00      5,288.00             14.00
# 2                 40,825.00      5,828.00              7.00
# 3                 39,780.00      5,739.00              9.00
# 4                 40,158.00      5,795.00             23.00
# 5                 38,031.00      5,223.00             19.00
# 6                 36,969.00      5,333.00              7.00
# 7                 36,561.00      5,771.00             22.00
# 8                 33,139.00      5,406.00             16.00
# 9                 35,306.00      5,483.00             13.00
# 10                32,381.00      5,120.00             15.00
# 11                31,289.00      4,089.00             11.00
#
# Primary Type  PUBLIC PEACE VIOLATION  RITUALISM   ROBBERY  SEX OFFENSE  \
# 0                           3,001.00       3.00 21,640.00     2,556.00
# 1                           2,957.00       1.00 16,131.00     1,932.00
# 2                           4,088.00       3.00 19,149.00     2,287.00
# 3                           3,895.00       1.00 20,099.00     2,226.00
# 4                           4,913.00       1.00 22,677.00     2,717.00
# 5                           4,346.00       0.00 22,682.00     2,753.00
# 6                           3,872.00       1.00 23,793.00     2,792.00
# 7                           3,618.00       3.00 24,153.00     2,608.00
# 8                           4,039.00       3.00 23,086.00     2,514.00
# 9                           4,006.00       3.00 24,605.00     2,247.00
# 10                          3,060.00       2.00 22,568.00     1,973.00
# 11                          2,670.00       3.00 22,553.00     1,746.00
#
# Primary Type  STALKING      THEFT  WEAPONS VIOLATION
# 0               389.00 113,371.00           7,913.00
# 1               327.00  97,059.00           6,482.00
# 2               404.00 116,074.00           8,169.00
# 3               403.00 119,459.00           8,537.00
# 4               411.00 130,436.00          10,102.00
# 5               405.00 131,832.00           9,308.00
# 6               385.00 138,566.00           8,792.00
# 7               361.00 139,056.00           8,924.00
# 8               345.00 127,194.00           8,499.00
# 9               357.00 128,819.00           8,390.00
# 10              362.00 114,972.00           7,235.00
# 11              291.00 110,885.00           6,690.00

# %%
# loop over all primary types
crime_type = list(crime_mo_type['Primary Type'].unique())
crime_type
# Out:
# ['ARSON',
#  'ASSAULT',
#  'BATTERY',
#  'BURGLARY',
#  'CONCEALED CARRY LICENSE VIOLATION',
#  'CRIM SEXUAL ASSAULT',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'CRIMINAL TRESPASS',
#  'DECEPTIVE PRACTICE',
#  'DOMESTIC VIOLENCE',
#  'GAMBLING',
#  'HOMICIDE',
#  'HUMAN TRAFFICKING',
#  'INTERFERENCE WITH PUBLIC OFFICER',
#  'INTIMIDATION',
#  'KIDNAPPING',
#  'LIQUOR LAW VIOLATION',
#  'MOTOR VEHICLE THEFT',
#  'NARCOTICS',
#  'NON - CRIMINAL',
#  'NON-CRIMINAL',
#  'NON-CRIMINAL (SUBJECT SPECIFIED)',
#  'OBSCENITY',
#  'OFFENSE INVOLVING CHILDREN',
#  'OTHER NARCOTIC VIOLATION',
#  'OTHER OFFENSE',
#  'PROSTITUTION',
#  'PUBLIC INDECENCY',
#  'PUBLIC PEACE VIOLATION',
#  'RITUALISM',
#  'ROBBERY',
#  'SEX OFFENSE',
#  'STALKING',
#  'THEFT',
#  'WEAPONS VIOLATION']

# %%
# create a df that has each primary type max and min and its month
result = pd.DataFrame()
for crime in crime_type:
    max_mo = crime_mo_type_piv['MonthName'].loc[crime_mo_type_piv[crime].idxmax()]
    min_mo = crime_mo_type_piv['MonthName'].loc[crime_mo_type_piv[crime].idxmin()]
    
    row = {
    "Primary Type": crime,
    "Max Month": max_mo,
    "Min Month": min_mo}
    
    result = result.append(row, ignore_index=True)
    
result
# Out:
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
# /var/folders/dj/tq7kx_ys6m161zqrzvh_73q80000gn/T/ipykernel_41203/1649650297.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = result.append(row, ignore_index=True)
#                          Primary Type  Max Month Min Month
# 0                               ARSON       July  February
# 1                             ASSAULT        May  December
# 2                             BATTERY        May  December
# 3                            BURGLARY     August  February
# 4   CONCEALED CARRY LICENSE VIOLATION  September  December
# 5                 CRIM SEXUAL ASSAULT       July  December
# 6                     CRIMINAL DAMAGE        May  February
# 7             CRIMINAL SEXUAL ASSAULT       June  December
# 8                   CRIMINAL TRESPASS      March  December
# 9                  DECEPTIVE PRACTICE    January  February
# 10                  DOMESTIC VIOLENCE    January   January
# 11                           GAMBLING     August  December
# 12                           HOMICIDE       July  February
# 13                  HUMAN TRAFFICKING  September  November
# 14   INTERFERENCE WITH PUBLIC OFFICER        May  December
# 15                       INTIMIDATION    October  December
# 16                         KIDNAPPING        May  February
# 17               LIQUOR LAW VIOLATION       June  December
# 18                MOTOR VEHICLE THEFT    October  February
# 19                          NARCOTICS      March  December
# 20                     NON - CRIMINAL       June      July
# 21                       NON-CRIMINAL    October      July
# 22   NON-CRIMINAL (SUBJECT SPECIFIED)    January       May
# 23                          OBSCENITY    October  February
# 24         OFFENSE INVOLVING CHILDREN    January  November
# 25           OTHER NARCOTIC VIOLATION        May   October
# 26                      OTHER OFFENSE      March  December
# 27                       PROSTITUTION    January  December
# 28                   PUBLIC INDECENCY        May   January
# 29             PUBLIC PEACE VIOLATION        May  December
# 30                          RITUALISM    January      June
# 31                            ROBBERY    October  February
# 32                        SEX OFFENSE       July  December
# 33                           STALKING        May  December
# 34                              THEFT     August  February
# 35                  WEAPONS VIOLATION        May  February

# %% [markdown]
# The pattern is May with highest whilst Feb with lowest and it is a mixed result. In fact, the dataframe above suggests that CRIMINAL DAMAGE, KIDNAPPING and WEAPONS VIOLATION completely follow the pattern.
#
# Additionally, I plan to categorize the pattern as the end of winter and end of spring, then perhaps find more months that match the trend .
